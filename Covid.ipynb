# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Data/data.csv")
df.head(10)
# Out:
#   YearWeekISO ReportingCountry  Denominator  NumberDosesReceived  \
# 0    2020-W53               AT    7388778.0              61425.0
# 1    2020-W53               AT    7388778.0                  0.0
# 2    2020-W53               AT    7388778.0                  0.0
# 3    2020-W53               AT    7388778.0                  0.0
# 4    2020-W53               AT    7388778.0                  0.0
# 5    2020-W53               AT    7388778.0                  0.0
# 6    2020-W53               AT    7388778.0                  0.0
# 7    2020-W53               AT    7388778.0                  0.0
# 8    2020-W53               AT    7388778.0                  0.0
# 9    2020-W53               AT    7388778.0                  0.0
#
#    NumberDosesExported  FirstDose  FirstDoseRefused  SecondDose  \
# 0                  0.0       5344               NaN           0
# 1                  0.0          0               NaN           0
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        YearWeekISO ReportingCountry  Denominator  NumberDosesReceived  \
# 0         2020-W53               AT    7388778.0              61425.0
# 1         2020-W53               AT    7388778.0                  0.0
# 2         2020-W53               AT    7388778.0                  0.0
# 3         2020-W53               AT    7388778.0                  0.0
# 4         2020-W53               AT    7388778.0                  0.0
# ...            ...              ...          ...                  ...
# 612980    2023-W02               SK     688658.0                  0.0
# 612981    2023-W02               SK     407927.0                  0.0
# 612982    2023-W02               SK     407927.0                  0.0
# 612983    2023-W02               SK     189121.0                  0.0
# 612984    2023-W02               SK     189121.0                  0.0
#
#         NumberDosesExported  FirstDose  FirstDoseRefused  SecondDose  \
# ...

# %%
df.shape
# Out:
# (612985, 16)

# %%
df.dtypes
# Out:
# YearWeekISO             object
# ReportingCountry        object
# Denominator            float64
# NumberDosesReceived    float64
# NumberDosesExported    float64
# FirstDose                int64
# FirstDoseRefused       float64
# SecondDose               int64
# DoseAdditional1          int64
# DoseAdditional2          int64
# DoseAdditional3          int64
# UnknownDose              int64
# Region                  object
# TargetGroup             object
# Vaccine                 object
# Population               int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# YearWeekISO                 0
# ReportingCountry            0
# Denominator            288735
# NumberDosesReceived    536678
# NumberDosesExported    531268
# FirstDose                   0
# FirstDoseRefused       611538
# SecondDose                  0
# DoseAdditional1             0
# DoseAdditional2             0
# DoseAdditional3             0
# UnknownDose                 0
# Region                      0
# TargetGroup                 0
# Vaccine                     0
# Population                  0
# dtype: int64

# %%
#df.drop(['Denominator'], axis=1, inplace=True)
df['Denominator'].fillna(value=df['Denominator'].mean(), inplace=True)
df.drop(['NumberDosesReceived'], axis=1, inplace=True)
df.drop(['NumberDosesExported'], axis=1, inplace=True)
df.drop(['FirstDoseRefused'], axis=1, inplace=True)

# %%
df.head(10)
# Out:
#   YearWeekISO ReportingCountry  Denominator  FirstDose  SecondDose  \
# 0    2020-W53               AT    7388778.0       5344           0
# 1    2020-W53               AT    7388778.0          0           0
# 2    2020-W53               AT    7388778.0          0           0
# 3    2020-W53               AT    7388778.0          0           0
# 4    2020-W53               AT    7388778.0          0           0
# 5    2020-W53               AT    7388778.0          0           0
# 6    2020-W53               AT    7388778.0          0           0
# 7    2020-W53               AT    7388778.0          0           0
# 8    2020-W53               AT    7388778.0          0           0
# 9    2020-W53               AT    7388778.0          2           0
#
#    DoseAdditional1  DoseAdditional2  DoseAdditional3  UnknownDose Region  \
# 0                0                0                0            0     AT
# 1                0                0                0            0     AT
# ...

# %%
df.describe()
# Out:
#         Denominator     FirstDose    SecondDose  DoseAdditional1  \
# count  6.129850e+05  6.129850e+05  6.129850e+05     6.129850e+05
# mean   1.474230e+06  1.521585e+03  1.385056e+03     1.096870e+03
# std    3.510049e+06  2.673334e+04  2.573505e+04     2.918069e+04
# min    9.810000e+02  0.000000e+00  0.000000e+00     0.000000e+00
# 25%    2.449860e+05  0.000000e+00  0.000000e+00     0.000000e+00
# 50%    1.474230e+06  0.000000e+00  0.000000e+00     0.000000e+00
# 75%    1.474230e+06  3.000000e+00  1.000000e+00     0.000000e+00
# max    6.941109e+07  4.021725e+06  4.149195e+06     6.647768e+06
#
#        DoseAdditional2  DoseAdditional3    UnknownDose    Population
# count     6.129850e+05    612985.000000  612985.000000  6.129850e+05
# mean      2.793054e+02        28.159927      12.332308  1.595745e+07
# std       6.234364e+03      1017.265695    1282.438847  1.764787e+07
# min       0.000000e+00         0.000000       0.000000  3.905500e+04
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 612985 entries, 0 to 612984
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   YearWeekISO       612985 non-null  object
#  1   ReportingCountry  612985 non-null  object
#  2   Denominator       612985 non-null  float64
#  3   FirstDose         612985 non-null  int64
#  4   SecondDose        612985 non-null  int64
#  5   DoseAdditional1   612985 non-null  int64
#  6   DoseAdditional2   612985 non-null  int64
#  7   DoseAdditional3   612985 non-null  int64
#  8   UnknownDose       612985 non-null  int64
#  9   Region            612985 non-null  object
#  10  TargetGroup       612985 non-null  object
#  11  Vaccine           612985 non-null  object
#  12  Population        612985 non-null  int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 60.8+ MB

# %%
df.corr()
# Out:
#                  Denominator  FirstDose  SecondDose  DoseAdditional1  \
# Denominator         1.000000   0.271699    0.265855         0.198166
# FirstDose           0.271699   1.000000    0.677391         0.071229
# SecondDose          0.265855   0.677391    1.000000         0.118885
# DoseAdditional1     0.198166   0.071229    0.118885         1.000000
# DoseAdditional2     0.203245   0.000022    0.003476         0.030304
# DoseAdditional3     0.105958  -0.001009   -0.000790         0.003999
# UnknownDose         0.000241  -0.000436   -0.000447         0.000437
# Population          0.204287   0.100647    0.097395         0.071106
#
#                  DoseAdditional2  DoseAdditional3  UnknownDose  Population
# Denominator             0.203245         0.105958     0.000241    0.204287
# FirstDose               0.000022        -0.001009    -0.000436    0.100647
# SecondDose              0.003476        -0.000790    -0.000447    0.097395
# ...

# %%
df.shape
# Out:
# (612985, 13)

# %%
df.isnull().sum()
# Out:
# YearWeekISO         0
# ReportingCountry    0
# Denominator         0
# FirstDose           0
# SecondDose          0
# DoseAdditional1     0
# DoseAdditional2     0
# DoseAdditional3     0
# UnknownDose         0
# Region              0
# TargetGroup         0
# Vaccine             0
# Population          0
# dtype: int64

# %%
sns.heatmap(df.isnull(), yticklabels='False', cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
import missingno as no
no.bar(df, color='blue')
# Out:
# <AxesSubplot:>

# %%
df1 = df['Vaccine'].value_counts()
plt.pie(df1.values, labels=df1.index, autopct='%0.2f%%')
plt.title('Vaccine Percentage', fontsize=15)
plt.show()

# %%
data = df['Vaccine'].value_counts()
data = data.to_frame()

# %%
plt.bar(data.index,data['Vaccine'], color ='maroon',
        width = 0.4)
# Out:
# <BarContainer object of 18 artists>

# %%
df['Vaccine'].value_counts()
# Out:
# COM          94884
# MOD          91325
# AZ           84035
# JANSS        83997
# NVXD         69888
# UNK          57848
# COMBA.1      41111
# COMBA.4-5    40596
# VLA          35628
# MODBA.1       3891
# BECNBG        2077
# COMBIV        1806
# MODBIV        1714
# SGSK          1422
# SIN           1114
# MODBA.4-5      755
# SPU            683
# BHACOV         211
# Name: Vaccine, dtype: int64

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %%
data['Vaccine'].plot(kind='box')
plt.show()

# %%
data.describe()
# Out:
#             Vaccine
# count     18.000000
# mean   34054.722222
# std    37143.440035
# min      211.000000
# 25%     1495.000000
# 50%    19759.500000
# 75%    66878.000000
# max    94884.000000

# %%
data
# Out:
#            Vaccine
# COM          94884
# MOD          91325
# AZ           84035
# JANSS        83997
# NVXD         69888
# UNK          57848
# COMBA.1      41111
# COMBA.4-5    40596
# VLA          35628
# MODBA.1       3891
# BECNBG        2077
# COMBIV        1806
# MODBIV        1714
# SGSK          1422
# SIN           1114
# MODBA.4-5      755
# SPU            683
# BHACOV         211

# %%
from scipy.stats import norm
import statistics

# %%
mean = statistics.mean(data['Vaccine'])
sd = statistics.stdev(data['Vaccine'])
  
plt.plot(data['Vaccine'], norm.pdf(data['Vaccine'], mean, sd))
plt.show()

# %%
data.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Vaccine'}>]], dtype=object)

# %%
data.drop(['SIN','MODBA.1','BECNBG','COMBIV','SGSK','MODBA.4-5','SPU','BHACOV'] ,axis=0,inplace=True)

# %%
data.drop(['MODBIV'] ,axis=0,inplace=True)

# %%
data
# Out:
#            Vaccine
# COM          94884
# MOD          91325
# AZ           84035
# JANSS        83997
# NVXD         69888
# UNK          57848
# COMBA.1      41111
# COMBA.4-5    40596
# VLA          35628

# %%
plt.bar(data.index,data['Vaccine'], color ='maroon',
        width = 0.4)
# Out:
# <BarContainer object of 9 artists>

# %%
data['Vaccine'].plot(kind='box')
plt.show()

# %%
mean = statistics.mean(data['Vaccine'])
sd = statistics.stdev(data['Vaccine'])
  
plt.plot(data['Vaccine'], norm.pdf(data['Vaccine'], mean, sd))
plt.show()

# %%
df = df[df['Vaccine'] != 'SIN']
df = df[df['Vaccine'] != 'MODBA.1']
df = df[df['Vaccine'] != 'BECNBG']
df = df[df['Vaccine'] != 'COMBIV']
df = df[df['Vaccine'] != 'SGSK']
df = df[df['Vaccine'] != 'MODBA.4-5']
df = df[df['Vaccine'] != 'SPU']
df = df[df['Vaccine'] != 'BHACOV']
df = df[df['Vaccine'] != 'MODBIV']

# %%
df['Vaccine'].value_counts()
# Out:
# COM          94884
# MOD          91325
# AZ           84035
# JANSS        83997
# NVXD         69888
# UNK          57848
# COMBA.1      41111
# COMBA.4-5    40596
# VLA          35628
# Name: Vaccine, dtype: int64

# %%
df1 = df['Vaccine'].value_counts()
plt.pie(df1.values, labels=df1.index, autopct='%0.2f%%')
plt.title('Vaccine Percentage', fontsize=15)
plt.show()

# %%
df.head(15)
# Out:
#    YearWeekISO ReportingCountry  Denominator  FirstDose  SecondDose  \
# 0     2020-W53               AT    7388778.0       5344           0
# 1     2020-W53               AT    7388778.0          0           0
# 2     2020-W53               AT    7388778.0          0           0
# 4     2020-W53               AT    7388778.0          0           0
# 6     2020-W53               AT    7388778.0          0           0
# 7     2020-W53               AT    7388778.0          0           0
# 8     2020-W53               AT    7388778.0          0           0
# 9     2020-W53               AT    7388778.0          2           0
# 10    2020-W53               AT    7388778.0          0           0
# 11    2020-W53               AT     433755.0          0           0
# 12    2020-W53               AT     433755.0          1           0
# 13    2020-W53               AT     433755.0          0           0
# 15    2020-W53               AT     433755.0          0           0
# ...

# %%
df['TargetGroup'].value_counts()
# Out:
# ALL         63083
# Age25_49    47567
# Age50_59    47217
# Age60_69    47151
# Age18_24    47049
# Age70_79    46948
# Age80+      46652
# Age15_17    40247
# Age10_14    39455
# AgeUNK      38877
# Age5_9      38563
# Age0_4      36717
# Age<18      33950
# HCW         17079
# LTCF         6219
# 1_Age60+     1269
# 1_Age<60     1269
# Name: TargetGroup, dtype: int64

# %%
df1 = df['TargetGroup'].value_counts()
plt.pie(df1.values, labels=df1.index, autopct='%0.2f%%')
plt.title('TargetGroup', fontsize=15)
plt.show()

# %%
df = df[df['TargetGroup'] != 'HCW']
df = df[df['TargetGroup'] != 'LTCF']     
df = df[df['TargetGroup'] != '1_Age60+']
df = df[df['TargetGroup'] != '1_Age<60']
df = df[df['TargetGroup'] != 'ALL']
df
# Out:
#        YearWeekISO ReportingCountry  Denominator  FirstDose  SecondDose  \
# 11        2020-W53               AT     433755.0          0           0
# 12        2020-W53               AT     433755.0          1           0
# 13        2020-W53               AT     433755.0          0           0
# 15        2020-W53               AT     433755.0          0           0
# 16        2020-W53               AT     433755.0          0           0
# ...            ...              ...          ...        ...         ...
# 612980    2023-W02               SK     688658.0          0           0
# 612981    2023-W02               SK     407927.0          0           0
# 612982    2023-W02               SK     407927.0          0           0
# 612983    2023-W02               SK     189121.0          0           0
# 612984    2023-W02               SK     189121.0          0           0
#
#         DoseAdditional1  DoseAdditional2  DoseAdditional3  UnknownDose Region  \
# ...

# %%
df['TargetGroup'].value_counts()
# Out:
# Age25_49    47567
# Age50_59    47217
# Age60_69    47151
# Age18_24    47049
# Age70_79    46948
# Age80+      46652
# Age15_17    40247
# Age10_14    39455
# AgeUNK      38877
# Age5_9      38563
# Age0_4      36717
# Age<18      33950
# Name: TargetGroup, dtype: int64

# %%
df1 = df['TargetGroup'].value_counts()
plt.pie(df1.values, labels=df1.index, autopct='%0.2f%%')
plt.title('TargetGroup', fontsize=15)
plt.show()

# %%
data = df['TargetGroup'].value_counts()
data = data.to_frame()

# %%
data
# Out:
#           TargetGroup
# Age25_49        47567
# Age50_59        47217
# Age60_69        47151
# Age18_24        47049
# Age70_79        46948
# Age80+          46652
# Age15_17        40247
# Age10_14        39455
# AgeUNK          38877
# Age5_9          38563
# Age0_4          36717
# Age<18          33950

# %%
data.describe()
# Out:
#         TargetGroup
# count     12.000000
# mean   42532.750000
# std     5016.159689
# min    33950.000000
# 25%    38798.500000
# 50%    43449.500000
# 75%    47074.500000
# max    47567.000000

# %%
data['TargetGroup'].plot(kind='box')
plt.show()

# %%
df
# Out:
#        YearWeekISO ReportingCountry  Denominator  FirstDose  SecondDose  \
# 11        2020-W53               AT     433755.0          0           0
# 12        2020-W53               AT     433755.0          1           0
# 13        2020-W53               AT     433755.0          0           0
# 15        2020-W53               AT     433755.0          0           0
# 16        2020-W53               AT     433755.0          0           0
# ...            ...              ...          ...        ...         ...
# 612980    2023-W02               SK     688658.0          0           0
# 612981    2023-W02               SK     407927.0          0           0
# 612982    2023-W02               SK     407927.0          0           0
# 612983    2023-W02               SK     189121.0          0           0
# 612984    2023-W02               SK     189121.0          0           0
#
#         DoseAdditional1  DoseAdditional2  DoseAdditional3  UnknownDose Region  \
# ...

# %%
df['Region'].value_counts()
# Out:
# FI1C2    11880
# FI194    11880
# FI193    11880
# FI1D3    11880
# FI1D8    11880
#          ...
# FRY5       763
# FRB        763
# LT01       474
# LT02       474
# DE         109
# Name: Region, Length: 90, dtype: int64

# %%
data = df['Region'].value_counts()
data = data.to_frame()
data
# Out:
#        Region
# FI1C2   11880
# FI194   11880
# FI193   11880
# FI1D3   11880
# FI1D8   11880
# ...       ...
# FRY5      763
# FRB       763
# LT01      474
# LT02      474
# DE        109
#
# [90 rows x 1 columns]

# %%
mean = statistics.mean(data['Region'])
sd = statistics.stdev(data['Region'])
  
plt.plot(data['Region'], norm.pdf(data['Region'], mean, sd))
plt.show()

# %%
data['Region'].plot(kind='box')
plt.show()
